# %% [markdown]
# ## Assignments
#
# ## File : Pandas Assignment 01
#
# ### Topic : Exercise 1- 5
#
# #### Submitted by: Anoop V H
#
#
# ##### Version : 1.0
#
# ##### Date's:
# ##### Start date of assignment : Feb 16, 2020
# ##### First Submission date : Feb 22,2020

# %% [markdown]
# ## 1. Print your slightly cleaned-up view of the movies dataframe; specifically, use the view resulting from problem 3a on HW#2. (Notice how Jupyter automatically elides most of the data to show you just a head/tail-oriented sample of its content.)

# %%
import pandas as pd
import numpy as np

mov_df=pd.DataFrame(pd.read_csv("movie_metadata.csv"))

mov_df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# ## 2. Use the dataframe info method to get a summary of the nature of the movies dataframe.

# %%
mov_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# ...

# %% [markdown]
# ## 3. Use the describe method to get a sense of the numeric columns’ data distributions in the movies dataframe.

# %%
mov_df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %% [markdown]
# ## 4. List the movie ids, titles, and genres for movies released in 2015 whose genres include ‘Children’.

# %%
mov_sub_df=pd.read_csv("movie_metadata.csv",usecols=['movie_title','title_year','plot_keywords'])
#mov_sub_df[((mov_sub_df['plot_keywords'].str.match('children')) & ((mov_sub_df['title_year']==2015))]
mov_sub_df.head()
# Out:
#                                          movie_title  \
# 0                                           AvatarÂ
# 1         Pirates of the Caribbean: At World's EndÂ
# 2                                          SpectreÂ
# 3                            The Dark Knight RisesÂ
# 4  Star Wars: Episode VII - The Force AwakensÂ   ...
#
#                                        plot_keywords  title_year
# 0             avatar|future|marine|native|paraplegic      2009.0
# 1  goddess|marriage ceremony|marriage proposal|pi...      2007.0
# 2                bomb|espionage|sequel|spy|terrorist      2015.0
# 3  deception|imprisonment|lawlessness|police offi...      2012.0
# 4                                                NaN         NaN

# %%
temp=mov_sub_df.notnull

# %%
temp[temp.plot_keywords.isin(['Children'])]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-0f7f0fc6cafb> in <module>
# ----> 1 temp[temp.plot_keywords.isin(['Children'])]
#
# AttributeError: 'function' object has no attribute 'plot_keywords'

# %% [markdown]
# ## 5. Examine the distribution of movies over time by printing, for each distinct release year value, the number of movies released in that year.

# %%
mov_df.groupby(["title_year"]).sum()
# Out:
#             num_critic_for_reviews  duration  director_facebook_likes  \
# title_year
# 1916.0                        69.0     123.0                    204.0
# 1920.0                         1.0     110.0                      0.0
# 1925.0                        48.0     151.0                     54.0
# 1927.0                       260.0     145.0                    756.0
# 1929.0                       107.0     210.0                     25.0
# ...                            ...       ...                      ...
# 2012.0                     51500.0   23298.0                 116944.0
# 2013.0                     52320.0   25510.0                  98166.0
# 2014.0                     42752.0   26462.0                 141060.0
# 2015.0                     36152.0   23749.0                  91344.0
# 2016.0                     15889.0   11621.0                  34990.0
#
#             actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# title_year
# ...
